# %%
pip install torch_geometric
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch_geometric
#   Downloading torch_geometric-2.3.0.tar.gz (616 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 616.2/616.2 kB 30.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch_geometric) (3.1.2)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.9/dist-packages (from torch_geometric) (3.0.9)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from torch_geometric) (1.2.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.9/dist-packages (from torch_geometric) (5.9.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from torch_geometric) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from torch_geometric) (2.27.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from torch_geometric) (1.10.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from torch_geometric) (4.65.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch_geometric) (2.1.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->torch_geometric) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->torch_geometric) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->torch_geometric) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->torch_geometric) (3.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->torch_geometric) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->torch_geometric) (3.1.0)
# Building wheels for collected packages: torch_geometric
#   Building wheel for torch_geometric (pyproject.toml) ... done
#   Created wheel for torch_geometric: filename=torch_geometric-2.3.0-py3-none-any.whl size=909897 sha256=48ae89cf8d27715fd0ea9b7032d730f5dd9074fee29637bc66957facd486574b
#   Stored in directory: /root/.cache/pip/wheels/cd/7d/6b/17150450b80b4a3656a84330e22709ccd8dc0f8f4773ba4133
# Successfully built torch_geometric
# Installing collected packages: torch_geometric
# Successfully installed torch_geometric-2.3.0

# %%
pip install scanpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scanpy
#   Downloading scanpy-1.9.3-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 46.4 MB/s eta 0:00:00
# Collecting anndata>=0.7.4
#   Downloading anndata-0.9.1-py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.0/103.0 kB 12.3 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.4 in /usr/local/lib/python3.9/dist-packages (from scanpy) (3.7.1)
# Collecting umap-learn>=0.3.10
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 8.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: statsmodels>=0.10.0rc2 in /usr/local/lib/python3.9/dist-packages (from scanpy) (0.13.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from scanpy) (23.1)
# Collecting session-info
#   Downloading session_info-1.0.0.tar.gz (24 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: seaborn in /usr/local/lib/python3.9/dist-packages (from scanpy) (0.12.2)
# Requirement already satisfied: h5py>=3 in /usr/local/lib/python3.9/dist-packages (from scanpy) (3.8.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from scanpy) (1.2.0)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.9/dist-packages (from scanpy) (1.5.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from scanpy) (4.65.0)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.9/dist-packages (from scanpy) (1.2.2)
# Requirement already satisfied: natsort in /usr/local/lib/python3.9/dist-packages (from scanpy) (8.3.1)
# Requirement already satisfied: numba>=0.41.0 in /usr/local/lib/python3.9/dist-packages (from scanpy) (0.56.4)
# Requirement already satisfied: scipy>=1.4 in /usr/local/lib/python3.9/dist-packages (from scanpy) (1.10.1)
# Requirement already satisfied: networkx>=2.3 in /usr/local/lib/python3.9/dist-packages (from scanpy) (3.1)
# Requirement already satisfied: patsy in /usr/local/lib/python3.9/dist-packages (from scanpy) (0.5.3)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.9/dist-packages (from scanpy) (1.22.4)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.4->scanpy) (4.39.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.4->scanpy) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.4->scanpy) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.4->scanpy) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.4->scanpy) (5.12.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.4->scanpy) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.4->scanpy) (1.0.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.4->scanpy) (8.4.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba>=0.41.0->scanpy) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from numba>=0.41.0->scanpy) (67.6.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0->scanpy) (2022.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.22->scanpy) (3.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from patsy->scanpy) (1.16.0)
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.10.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 52.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting stdlib_list
#   Downloading stdlib_list-0.8.0-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.5/63.5 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib>=3.4->scanpy) (3.15.0)
# Building wheels for collected packages: umap-learn, session-info, pynndescent
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82830 sha256=70f1ea9390e7a0a3494ef356ee4522255fe3658b6d52d79c567130c9646fd19d
#   Stored in directory: /root/.cache/pip/wheels/f4/3e/1c/596d0a463d17475af648688443fa4846fef624d1390339e7e9
#   Building wheel for session-info (setup.py) ... done
#   Created wheel for session-info: filename=session_info-1.0.0-py3-none-any.whl size=8042 sha256=fa37b50e12c42af41642e02e6e02a92f89938da017b02f8780497a2601ebdc50
#   Stored in directory: /root/.cache/pip/wheels/d4/fc/2e/00ca60bac7954b84907efd41baa9b4853500eaeec4228410c6
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.10-py3-none-any.whl size=55640 sha256=ea8831aacfe896cc2a10d4b4811ceec7a30b99f03becae52e6af85a4d2a2fb47
#   Stored in directory: /root/.cache/pip/wheels/12/f9/4d/ec5ad1c823c710fcc4473669fdcffc8891f4bc398c841af22e
# Successfully built umap-learn session-info pynndescent
# Installing collected packages: stdlib_list, session-info, pynndescent, anndata, umap-learn, scanpy
# Successfully installed anndata-0.9.1 pynndescent-0.5.10 scanpy-1.9.3 session-info-1.0.0 stdlib_list-0.8.0 umap-learn-0.5.3

# %%
pip install igraph
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting igraph
#   Downloading igraph-0.10.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 42.8 MB/s eta 0:00:00
# Collecting texttable>=1.6.2
#   Downloading texttable-1.6.7-py2.py3-none-any.whl (10 kB)
# Installing collected packages: texttable, igraph
# Successfully installed igraph-0.10.4 texttable-1.6.7

# %%
pip install louvain
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting louvain
#   Downloading louvain-0.8.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 33.5 MB/s eta 0:00:00
# Requirement already satisfied: igraph<0.11,>=0.10.0 in /usr/local/lib/python3.9/dist-packages (from louvain) (0.10.4)
# Requirement already satisfied: texttable>=1.6.2 in /usr/local/lib/python3.9/dist-packages (from igraph<0.11,>=0.10.0->louvain) (1.6.7)
# Installing collected packages: louvain
# Successfully installed louvain-0.8.0

# %%
import torch

# !pip uninstall torch-scatter torch-sparse torch-geometric torch-cluster  --y
# !pip install torch-scatter -f https://data.pyg.org/whl/torch-{torch.__version__}.html
# !pip install torch-sparse -f https://data.pyg.org/whl/torch-{torch.__version__}.html
# !pip install torch-cluster -f https://data.pyg.org/whl/torch-{torch.__version__}.html
# !pip install git+https://github.com/pyg-team/pytorch_geometric.git
# Out:
# WARNING: Skipping torch-scatter as it is not installed.
# WARNING: Skipping torch-sparse as it is not installed.
# Found existing installation: torch-geometric 2.3.0
# Uninstalling torch-geometric-2.3.0:
#   Successfully uninstalled torch-geometric-2.3.0
# WARNING: Skipping torch-cluster as it is not installed.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://data.pyg.org/whl/torch-2.0.0+cu118.html
# Collecting torch-scatter
#   Downloading https://data.pyg.org/whl/torch-2.0.0%2Bcu118/torch_scatter-2.1.1%2Bpt20cu118-cp39-cp39-linux_x86_64.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 36.8 MB/s eta 0:00:00
# Installing collected packages: torch-scatter
# Successfully installed torch-scatter-2.1.1+pt20cu118
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://data.pyg.org/whl/torch-2.0.0+cu118.html
# Collecting torch-sparse
#   Downloading https://data.pyg.org/whl/torch-2.0.0%2Bcu118/torch_sparse-0.6.17%2Bpt20cu118-cp39-cp39-linux_x86_64.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 33.1 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from torch-sparse) (1.10.1)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in /usr/local/lib/python3.9/dist-packages (from scipy->torch-sparse) (1.22.4)
# Installing collected packages: torch-sparse
# Successfully installed torch-sparse-0.6.17+pt20cu118
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://data.pyg.org/whl/torch-2.0.0+cu118.html
# Collecting torch-cluster
#   Downloading https://data.pyg.org/whl/torch-2.0.0%2Bcu118/torch_cluster-1.6.1%2Bpt20cu118-cp39-cp39-linux_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 62.7 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from torch-cluster) (1.10.1)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in /usr/local/lib/python3.9/dist-packages (from scipy->torch-cluster) (1.22.4)
# Installing collected packages: torch-cluster
# Successfully installed torch-cluster-1.6.1+pt20cu118
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/pyg-team/pytorch_geometric.git
#   Cloning https://github.com/pyg-team/pytorch_geometric.git to /tmp/pip-req-build-7tleyimq
#   Running command git clone --filter=blob:none --quiet https://github.com/pyg-team/pytorch_geometric.git /tmp/pip-req-build-7tleyimq
#   Resolved https://github.com/pyg-team/pytorch_geometric.git to commit 2fdf01e0cf451722af2f84cbab548d5c8d0e1b41
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from torch_geometric==2.4.0) (1.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from torch_geometric==2.4.0) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from torch_geometric==2.4.0) (2.27.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch_geometric==2.4.0) (3.1.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from torch_geometric==2.4.0) (1.2.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.9/dist-packages (from torch_geometric==2.4.0) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.9/dist-packages (from torch_geometric==2.4.0) (3.0.9)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from torch_geometric==2.4.0) (4.65.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch_geometric==2.4.0) (2.1.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->torch_geometric==2.4.0) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->torch_geometric==2.4.0) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->torch_geometric==2.4.0) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->torch_geometric==2.4.0) (3.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->torch_geometric==2.4.0) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->torch_geometric==2.4.0) (3.1.0)
# Building wheels for collected packages: torch_geometric
#   Building wheel for torch_geometric (pyproject.toml) ... done
#   Created wheel for torch_geometric: filename=torch_geometric-2.4.0-py3-none-any.whl size=920640 sha256=ced046023e4cedfc8b607a2c253ce56c9112f4c696790f5c7ea603026062d48e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-4nsu4s_n/wheels/e5/8a/bc/10228fa47bb01dd916740a9102c063c4e363e7dac6d55dba4a
# Successfully built torch_geometric
# Installing collected packages: torch_geometric
# Successfully installed torch_geometric-2.4.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Dataset

# %%
##############################################################################
#
#      This is just creating simplified dataset, don't need to run this, dataset is in github
#
###############################################################################

#These labels are from the 'fine-level' convention but if you want to lift the labels to broad-level to test accuracy there, 
#it's simply a matter of converting any label that contains 'macrophage' ( or macophage, as our biologists made some typos here) to the macrophage label; 
#anything containing 'T-cell' to simply 'T-cell'; same for B-cell and DC (dendritic cells; you will see DCs and DC1 + some qualifier); 
#the rest like NK; neutrophil; eosinophil; cortical sinus ... these can be left as is.
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/content/drive/MyDrive/Data Science for Healthcare/Final Project/region2_mouse_lymph.csv')
df.loc[df['cluster'].str.contains('Macophages|Macophages|macophages|Macrophages|macrophages' ), 'cluster'] = 'Macrophage'
df.loc[df['cluster'].str.contains('T cells|T helper cells'), 'cluster'] = 'T-cell'
df.loc[df['cluster'].str.contains('B cells'), 'cluster'] = 'B-cell'
df.loc[df['cluster'].str.contains('DC'), 'cluster'] = 'DC'
cell_type_info = df['cluster'].value_counts()
print(cell_type_info)

df.to_csv('/content/drive/MyDrive/Data Science for Healthcare/Final Project/region2_mouse_lymph_simplified.csv', index=False) 

sns.countplot(x = df['cluster'], order = df['cluster'].value_counts().index)
plt.xticks(rotation=90)
plt.xlabel('Cell Type')
plt.ylabel('Number of cells')
plt.title("Cell type distribution")
plt.show()
# Out:
# T-cell                      5919
# B-cell                      5660
# Macrophage                  1988
# DC                          1591
# Endothelial vessels         1344
# Unannotated                  471
# Lyve1+ Lymphatic vessels     401
# NK cells                      79
# Monocytes                     64
# Eosinophils                   40
# Neutrophils                   40
# Name: cluster, dtype: int64

# %%
import torch
import numpy as np
from builtins import range
from torch_geometric.data import InMemoryDataset, Data
from sklearn.metrics import pairwise_distances
import pandas as pd


def get_mouselymph_edge_index(pos, distance_thres):
    edge_list = []
    dists = pairwise_distances(pos)
    dists_mask = dists < distance_thres 
    np.fill_diagonal(dists_mask, 0) 
    edge_list = np.transpose(np.nonzero(dists_mask)).tolist()
    return edge_list

def load_mouselymph_data(filename, distance_thres, sample_rate, way):
    from sklearn.model_selection import train_test_split
    if way == 'naive':
        df = pd.read_csv(filename)
        X = df.iloc[:, 1:-1].values
        print(X)
        y = df['cluster']
        train_X, test_X, train_y, test_y = train_test_split(X, y, test_size=0.33, random_state=42)
        train_X_df = pd.DataFrame(train_X)
        
        # sample train set
        train_X_df = train_X_df.sample(n=round(sample_rate*len(train_X_df)), random_state=1)
        train_y_df = y[train_X_df.index]

        train_X = train_X_df.to_numpy()
        train_y = train_y_df.to_numpy()
        
        labeled_pos = train_X[:, -2:]
        unlabeled_pos = test_X[:, -2:]

        # convert string labels to index
        cell_types = np.sort(list(set(train_y))).tolist()
        cell_type_dict = {}
        inverse_dict = {}    
        for i, cell_type in enumerate(cell_types):
            cell_type_dict[cell_type] = i
            inverse_dict[i] = cell_type
        train_y = np.array([cell_type_dict[x] for x in train_y])
        test_y = np.array([cell_type_dict[x] for x in test_y])
        labeled_edges = get_mouselymph_edge_index(labeled_pos, distance_thres)
        unlabeled_edges = get_mouselymph_edge_index(unlabeled_pos, distance_thres)

    elif way == 'strat':
        df = pd.read_csv(filename)
        train, test = train_test_split(df, test_size=0.2, random_state=42, stratify=df['cluster'])
        train_df = pd.DataFrame(train)

        train_df_sampled = train_df.sample(n=round(sample_rate*len(train_df)), random_state=1)
        train_X_df = train_df_sampled.iloc[:, 1:-1]
        train_X = train_X_df.to_numpy()
        train_y = train_df_sampled['cluster'].to_numpy()

        test_df = pd.DataFrame(test)
        test_X = test_df.iloc[:, 1:-1].values
        test_y = test_df['cluster'].to_numpy()

        labeled_pos = train_X[:, -2:]
        unlabeled_pos = test_X[:, -2:]
        cell_types = np.sort(list(set(train_y))).tolist()
        cell_type_dict = {}
        inverse_dict = {}    
        for i, cell_type in enumerate(cell_types):
            cell_type_dict[cell_type] = i
            inverse_dict[i] = cell_type
        train_y = np.array([cell_type_dict[x] for x in train_y])
        test_y = np.array([cell_type_dict[x] for x in test_y])
        labeled_edges = get_mouselymph_edge_index(labeled_pos, distance_thres)
        unlabeled_edges = get_mouselymph_edge_index(unlabeled_pos, distance_thres)
        print(train_X.shape)
        print(test_X.shape)
    # return train_X, train_y, test_X, labeled_edges, unlabeled_edges, inverse_dict

    elif way == 'locx': # split train and test set basd on the x coordinate
        df = pd.read_csv(filename)
        df = df.sort_values('x')
        train_df = df.iloc[:int(len(df.index)/3)]
        train_X = train_df.iloc[:, 1:-1].to_numpy()
        train_y = train_df['cluster'].to_numpy()

        test_df = df.iloc[int(len(df.index)/3):]
        test_X = train_df.iloc[:, 1:-1].to_numpy()
        test_y = train_df['cluster'].to_numpy()
        
        labeled_pos = train_X[:, -2:]
        unlabeled_pos = test_X[:, -2:]
        cell_types = np.sort(list(set(train_y))).tolist()
        cell_type_dict = {}
        inverse_dict = {}    
        for i, cell_type in enumerate(cell_types):
            cell_type_dict[cell_type] = i
            inverse_dict[i] = cell_type
        train_y = np.array([cell_type_dict[x] for x in train_y])
        test_y = np.array([cell_type_dict[x] for x in test_y])
        labeled_edges = get_mouselymph_edge_index(labeled_pos, distance_thres)
        unlabeled_edges = get_mouselymph_edge_index(unlabeled_pos, distance_thres)
    return train_X, train_y, test_X, test_y, labeled_edges, unlabeled_edges, inverse_dict
    
class GraphDataset(InMemoryDataset):

    def __init__(self, labeled_X, labeled_y, unlabeled_X, labeled_edges, unlabeled_edges, transform=None,):
        self.root = '.'
        super(GraphDataset, self).__init__(self.root, transform)
        self.labeled_data = Data(x=torch.FloatTensor(labeled_X), edge_index=torch.LongTensor(labeled_edges).T, y=torch.LongTensor(labeled_y))
        self.unlabeled_data = Data(x=torch.FloatTensor(unlabeled_X), edge_index=torch.LongTensor(unlabeled_edges).T)

    def __len__(self):
        return 2

    def __getitem__(self, idx):
        return self.labeled_data, self.unlabeled_data

# %%
load_mouselymph_data('/content/drive/MyDrive/Data Science for Healthcare/Final Project/region2_mouse_lymph_simplified.csv', 50, 1, 'strat')
# Out:
# (14077, 32)
# (3520, 32)

# %% [markdown]
# # Model

# %%
##############################################################################
#
#      Some changes: 1) Add another SAGEConv layer in the Encoder; 
#                    2) Change the hidden dimension in Encoder model; 
#                    3) Created a naive GCN model
#
###############################################################################
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn import Parameter
from torch_geometric.nn import SAGEConv
from torch_geometric.nn import GCNConv

class NormedLinear(nn.Module):

    def __init__(self, in_features, out_features):
        super(NormedLinear, self).__init__()
        self.weight = Parameter(torch.Tensor(in_features, out_features))
        self.weight.data.uniform_(-1, 1).renorm_(2, 1, 1e-5).mul_(1e5)

    def forward(self, x):
        out = F.normalize(x, dim=1).mm(F.normalize(self.weight, dim=0))
        return 10 * out

class Encoder(nn.Module):
    def __init__(self, x_dim, num_cls):
        super(Encoder, self).__init__()
        self.x_dim = x_dim
        hid_dim = 512
        self.conv1 = nn.Linear(x_dim, hid_dim)
        self.relu = nn.ReLU()
        self.conv2 = SAGEConv(hid_dim, hid_dim)
        self.linear1 = NormedLinear(hid_dim, 128)
        self.conv3 = SAGEConv(128, 128)
        self.linear2 = NormedLinear(128, num_cls)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x)
        feat = x
        x = self.relu(x)
        x = self.conv2(x, edge_index)
        x = self.linear1(self.relu(x))
        out_feat = self.conv3(x, edge_index)
        out = self.linear2(self.relu(out_feat))
        # out_feat = x
        # out = self.linear(x)
        return out, feat, out_feat

class GCN(nn.Module):
    def __init__(self, x_dim, num_cls):
        super(GCN, self).__init__()
        torch.manual_seed(12345)
        hid_dim = 256
        self.conv1 = GCNConv(x_dim, hid_dim)
        self.conv2 = GCNConv(hid_dim, hid_dim)
        self.conv3 = GCNConv(hid_dim, 128)
        self.classifier = nn.Linear(128, num_cls)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        h = self.conv1(x, edge_index)
        feat = h
        h = h.tanh()
        h = self.conv2(h, edge_index)
        h = h.tanh()
        h = self.conv3(h, edge_index)
        out_feat = h.tanh()  # Final GNN embedding space.
        
        # Apply a final (linear) classifier.
        out = self.classifier(out_feat)

        return out, feat, out_feat

class FCNet(nn.Module):
    def __init__(self, x_dim, num_cls):
        super(FCNet, self).__init__()
        self.linear = NormedLinear(x_dim, num_cls)

    def forward(self, data):
        x = data.x
        out = self.linear(x)
        return out, x, x

# %% [markdown]
# # Utils

# %%
##############################################################################
#
#     No changes
#
###############################################################################
import torch
import torch.nn as nn
import os
import os.path
import torch.nn.functional as F

def prepare_save_dir(args, filename):
    """ Create saving directory."""
    runner_name = os.path.basename(filename).split(".")[0]
    model_dir = './experiments/{}/{}/'.format(runner_name, args.name)
    args.savedir = model_dir
    if not os.path.exists(args.savedir):
        os.makedirs(args.savedir)
    return args

def entropy(x):
    """ 
    Helper function to compute the entropy over the batch 
    input: batch w/ shape [b, num_classes]
    output: entropy value [is ideally -log(num_classes)]
    """
    EPS = 1e-8
    x_ =  torch.clamp(x, min = EPS)
    b =  x_ * torch.log(x_)

    if len(b.size()) == 2: # Sample-wise entropy
        return - b.sum(dim = 1).mean()
    elif len(b.size()) == 1: # Distribution-wise entropy
        return - b.sum()
    else:
        raise ValueError('Input tensor is %d-Dimensional' %(len(b.size())))

class MarginLoss(nn.Module):
    
    def __init__(self, m=0.2, weight=None, s=10):
        super(MarginLoss, self).__init__()
        self.m = m
        self.s = s
        self.weight = weight

    def forward(self, x, target):
        index = torch.zeros_like(x, dtype=torch.bool)
        index.scatter_(1, target.data.view(-1, 1), 1)
        x_m = x - self.m * self.s
    
        output = torch.where(index, x_m, x)
        return F.cross_entropy(output, target, weight=self.weight)

# %% [markdown]
# # Training & Evaluation

# %%
##############################################################################
#
#        Some changes: 1) nothing about predicting novel cell types
#                      2) Objective function: Just cross entropy
#                      3) Add accuracy
#
#
###############################################################################
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
from itertools import cycle
import copy
from torch_geometric.data import ClusterData, ClusterLoader
import scanpy as sc
from anndata import AnnData

class STELLAR:

    def __init__(self, args, dataset):
        self.args = args
        self.dataset = dataset
        args.input_dim = dataset.unlabeled_data.x.shape[-1]
        self.model = Encoder(args.input_dim, args.num_heads)
        self.model = self.model.to(args.device)

    # def train_supervised(self, args, model, device, dataset, optimizer, epoch):
    #     model.train()
    #     ce = nn.CrossEntropyLoss()
    #     sum_loss = 0

    #     labeled_graph = dataset.labeled_data
    #     labeled_data = ClusterData(labeled_graph, num_parts=100, recursive=False)
    #     labeled_loader = ClusterLoader(labeled_data, batch_size=args.batch_size, shuffle=True,
    #                                 num_workers=1)

    #     for batch_idx, labeled_x in enumerate(labeled_loader):
    #         labeled_x = labeled_x.to(device)
    #         optimizer.zero_grad()
    #         output, _, _ = model(labeled_x)
            
    #         loss = ce(output, labeled_x.y)
            
    #         optimizer.zero_grad()
    #         sum_loss += loss.item()
    #         loss.backward()
    #         optimizer.step()
    #     print('Loss: {:.6f}'.format(sum_loss / (batch_idx + 1)))

    # def est_seeds(self, args, model, device, dataset, clusters, num_seed_class):
    #     model.eval()
    #     entrs = np.array([])
    #     with torch.no_grad():
    #         labeled_graph, unlabeled_graph = dataset.labeled_data, dataset.unlabeled_data
    #         unlabeled_graph_cp = copy.deepcopy(unlabeled_graph)
    #         unlabeled_graph_cp = unlabeled_graph_cp.to(device)
    #         output, _, _ = model(unlabeled_graph_cp)
    #         prob = F.softmax(output, dim=1)
    #         entr = -torch.sum(prob * torch.log(prob), 1)
    #         entrs = np.append(entrs, entr.cpu().numpy())
        
    #     entrs_per_cluster = []
    #     for i in range(np.max(clusters)+1):
    #         locs = np.where(clusters == i)[0]
    #         entrs_per_cluster.append(np.mean(entrs[locs]))
    #     entrs_per_cluster = np.array(entrs_per_cluster)
    #     if num_seed_class > 0:
    #         novel_cluster_idxs = np.argsort(entrs_per_cluster)[-num_seed_class:]
    #     else:
    #         novel_cluster_idxs = []
    #     novel_label_seeds = np.zeros_like(clusters)
    #     largest_seen_id = torch.max(labeled_graph.y)
        
    #     for i, idx in enumerate(novel_cluster_idxs):
    #         novel_label_seeds[clusters == idx] = largest_seen_id + i + 1
    #     return novel_label_seeds

    # def train_epoch(self, args, model, device, dataset, optimizer, m, epoch):
    #     """ Train for 1 epoch."""
    #     model.train()
    #     bce = nn.BCELoss()
    #     ce = MarginLoss(m=-m)
    #     sum_loss = 0

    #     labeled_graph, unlabeled_graph = dataset.labeled_data, dataset.unlabeled_data
    #     labeled_data = ClusterData(labeled_graph, num_parts=100, recursive=False)
    #     labeled_loader = ClusterLoader(labeled_data, batch_size=args.batch_size, shuffle=True,
    #                                 num_workers=1)
    #     unlabeled_data = ClusterData(unlabeled_graph, num_parts=100, recursive=False)
    #     unlabeled_loader = ClusterLoader(unlabeled_data, batch_size=args.batch_size, shuffle=True,
    #                                 num_workers=1)
    #     unlabel_loader_iter = cycle(unlabeled_loader)

    #     for batch_idx, labeled_x in enumerate(labeled_loader):
    #         unlabeled_x = next(unlabel_loader_iter)
    #         unlabeled_ce_idx = torch.where(unlabeled_x.novel_label_seeds>0)[0]
    #         labeled_x, unlabeled_x = labeled_x.to(device), unlabeled_x.to(device)
    #         optimizer.zero_grad()
    #         labeled_output, labeled_feat, _ = model(labeled_x)
    #         unlabeled_output, unlabeled_feat, _ = model(unlabeled_x)
    #         labeled_len = len(labeled_output)
    #         batch_size = len(labeled_output) + len(unlabeled_output)
    #         output = torch.cat([labeled_output, unlabeled_output], dim=0)
    #         feat = torch.cat([labeled_feat, unlabeled_feat], dim=0)
            
    #         prob = F.softmax(output, dim=1)
    #         # Similarity labels
    #         feat_detach = feat.detach()
    #         feat_norm = feat_detach / torch.norm(feat_detach, 2, 1, keepdim=True)
    #         cosine_dist = torch.mm(feat_norm, feat_norm.t())

    #         pos_pairs = []
    #         target = labeled_x.y
    #         target_np = target.cpu().numpy()
            
    #         for i in range(labeled_len):
    #             target_i = target_np[i]
    #             idxs = np.where(target_np == target_i)[0]
    #             if len(idxs) == 1:
    #                 pos_pairs.append(idxs[0])
    #             else:
    #                 selec_idx = np.random.choice(idxs, 1)
    #                 while selec_idx == i:
    #                     selec_idx = np.random.choice(idxs, 1)
    #                 pos_pairs.append(int(selec_idx))
            
    #         unlabel_cosine_dist = cosine_dist[labeled_len:, :]
    #         vals, pos_idx = torch.topk(unlabel_cosine_dist, 2, dim=1)
    #         pos_idx = pos_idx[:, 1].cpu().numpy().flatten().tolist()
    #         pos_pairs.extend(pos_idx)
            
    #         pos_prob = prob[pos_pairs, :]
    #         pos_sim = torch.bmm(prob.view(batch_size, 1, -1), pos_prob.view(batch_size, -1, 1)).squeeze()
    #         ones = torch.ones_like(pos_sim)
    #         bce_loss = bce(pos_sim, ones)
    #         ce_idx = torch.cat((torch.arange(labeled_len), labeled_len+unlabeled_ce_idx))
    #         target = torch.cat((target, unlabeled_x.novel_label_seeds))
    #         ce_loss = ce(output[ce_idx], target[ce_idx])
    #         entropy_loss = entropy(torch.mean(prob, 0))
            
    #         loss = 1 * bce_loss + 1 * ce_loss - 0.3 * entropy_loss

    #         optimizer.zero_grad()
    #         sum_loss += loss.item()
    #         loss.backward()
    #         optimizer.step()

    #     print('Combined Loss: {:.6f}'.format(sum_loss / (batch_idx + 1)))

    def train_epoch(self, args, model, device, dataset, optimizer, m, epoch):
        labeled_graph = dataset.labeled_data
        labeled_data = ClusterData(labeled_graph, num_parts=100, recursive=False)
        labeled_loader = ClusterLoader(labeled_data, batch_size=args.batch_size, shuffle=True,
                                      num_workers=1)
        # print(labeled_loader)
        criterion = torch.nn.CrossEntropyLoss()
        sum_loss = 0
        corr_pred = 0

        for batch_idx, labeled_x in enumerate(labeled_loader):
          labeled_x = labeled_x.to(device)

          optimizer.zero_grad()
          out, _, _ = model(labeled_x)
          _, pred = out.max(1)

          corr_pred += (pred == labeled_x.y).sum()

          loss = criterion(out, labeled_x.y)
          sum_loss += loss.item()

          loss.backward()
          optimizer.step()
        
        acc = (corr_pred / len(dataset.labeled_data.x)).item()
        print('Combined Loss: {:.6f}'.format(sum_loss / len(labeled_loader)))
        print("Acc: {:.4f}".format(corr_pred / len(dataset.labeled_data.x)))
        return round(acc, 3)

    def pred(self):
        self.model.eval()
        preds = np.array([])
        confs = np.array([])
        with torch.no_grad():
            _, unlabeled_graph = self.dataset.labeled_data, self.dataset.unlabeled_data
            unlabeled_graph_cp = copy.deepcopy(unlabeled_graph)
            unlabeled_graph_cp = unlabeled_graph_cp.to(self.args.device)
            output, _, _ = self.model(unlabeled_graph_cp)
            prob = F.softmax(output, dim=1)
            conf, pred = prob.max(1)
            preds = np.append(preds, pred.cpu().numpy())
            confs = np.append(confs, conf.cpu().numpy())
        preds = preds.astype(int)
        print("#######", preds)
        unique, counts = np.unique(preds, return_counts=True)
        print("#######class instances", np.asarray((unique, counts)).T)
        mean_uncert = 1 - np.mean(confs)
        return mean_uncert, preds

    # def train(self):
    #     unlabel_x = self.dataset.unlabeled_data.x
    #     adata = AnnData(unlabel_x.numpy())
    #     sc.pp.neighbors(adata)
    #     sc.tl.louvain(adata, 1)
    #     clusters = adata.obs['louvain'].values
    #     clusters = clusters.astype(int)

    #     seed_model = FCNet(x_dim = self.args.input_dim, num_cls=torch.max(self.dataset.labeled_data.y)+1)
    #     seed_model = seed_model.to(self.args.device)
    #     seed_optimizer = optim.Adam(seed_model.parameters(), lr=1e-3, weight_decay=5e-2)
    #     for epoch in range(20):
    #         self.train_supervised(self.args, seed_model, self.args.device, self.dataset, seed_optimizer, epoch)

    #     novel_label_seeds = self.est_seeds(self.args, seed_model, self.args.device, self.dataset, clusters, self.args.num_seed_class)
    #     self.dataset.unlabeled_data.novel_label_seeds = torch.tensor(novel_label_seeds)
    #     # Set the optimizer
    #     optimizer = optim.Adam(self.model.parameters(), lr=self.args.lr, weight_decay=self.args.wd)

    #     print("[INFO]: Training starts")
    #     for epoch in range(self.args.epochs):
    #         mean_uncert, _ = self.pred()
    #         self.train_epoch(self.args, self.model, self.args.device, self.dataset, optimizer, mean_uncert, epoch)

    def train(self):
      # Set the optimizer
      optimizer = optim.Adam(self.model.parameters(), lr=self.args.lr, weight_decay=self.args.wd)

      print("[INFO]: Training starts")
      max_acc = 0
      for epoch in range(self.args.epochs):
          mean_uncert, _ = self.pred()
          acc = self.train_epoch(self.args, self.model, self.args.device, self.dataset, optimizer, mean_uncert, epoch)
          if acc > max_acc:
            max_acc = acc
      print("Highest Accuracy:", max_acc)

# %% [markdown]
# # Run

# %%
class Args():
  batch_size = 1
  dataset = "MouseLymph"
  seed = 1
  name = "STELLAR"
  epochs = 20
  lr = 1e-6
  wd = 0
  num_heads = 11
  num_seed_class = 0
  sample_rate = 1
  distance_thres = 20
  savedir = "./"
  cuda = torch.cuda.is_available()
  way = 'strat'
  device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
inverse_dict
# Out:
# {0: 'B-cell',
#  1: 'DC',
#  2: 'Endothelial vessels',
#  3: 'Eosinophils',
#  4: 'Lyve1+ Lymphatic vessels',
#  5: 'Macrophage',
#  6: 'Monocytes',
#  7: 'NK cells',
#  8: 'T-cell',
#  9: 'Unannotated'}

# %%
# import argparse
import numpy as np
import os
import torch

# parser = argparse.ArgumentParser(description='STELLAR')
# parser.add_argument('--dataset', default='Hubmap', help='dataset setting')
# parser.add_argument('--seed', type=int, default=1, metavar='S', help='random seed (default: 1)')
# parser.add_argument('--name', type=str, default='STELLAR')
# parser.add_argument('--epochs', type=int, default=20)
# parser.add_argument('--lr', type=float, default=1e-3)
# parser.add_argument('--wd', type=float, default=5e-2)
# parser.add_argument('--num-heads', type=int, default=22)
# parser.add_argument('--num-seed-class', type=int, default=0)
# parser.add_argument('--sample-rate', type=float, default=0.5)
# parser.add_argument('-b', '--batch-size', default=1, type=int,
#                 metavar='N',
#                 help='mini-batch size')
# parser.add_argument('--distance_thres', default=50, type=int)
# parser.add_argument('--savedir', type=str, default='./')
# args = parser.parse_args()

args = Args()

# Change the args here:

args.cuda = torch.cuda.is_available()
args.device = torch.device("cuda" if args.cuda else "cpu")

# Seed the run and create saving directory
args.name = '_'.join([args.dataset, args.name])

# I didn't figure out what __file__ is
# args = prepare_save_dir(args, __file__)
args = prepare_save_dir(args,'stellar-main')

# TODO: reroute the dataset files
if args.dataset == 'Hubmap':
    labeled_X, labeled_y, unlabeled_X, labeled_edges, unlabeled_edges, inverse_dict = load_hubmap_data('/content/drive/MyDrive/Data Science for Healthcare/Final Project/B004_training_dryad.csv', '/content/drive/MyDrive/Data Science for Healthcare/Final Project/B0056_unnanotated_dryad.csv', args.distance_thres, args.sample_rate)
    dataset = GraphDataset(labeled_X, labeled_y, unlabeled_X, labeled_edges, unlabeled_edges)
elif args.dataset == 'TonsilBE':
    labeled_X, labeled_y, unlabeled_X, labeled_edges, unlabeled_edges, inverse_dict = load_tonsilbe_data('/content/drive/MyDrive/Data Science for Healthcare/Final Project/BE_Tonsil_l3_dryad.csv', args.distance_thres, args.sample_rate)
    dataset = GraphDataset(labeled_X, labeled_y, unlabeled_X, labeled_edges, unlabeled_edges)
elif args.dataset == 'MouseLymph':
    labeled_X, labeled_y, unlabeled_X, unlabeled_y, labeled_edges, unlabeled_edges, inverse_dict = load_mouselymph_data('/content/drive/MyDrive/Data Science for Healthcare/Final Project/region2_mouse_lymph_simplified.csv', args.distance_thres, args.sample_rate, args.way)
    dataset = GraphDataset(labeled_X, labeled_y, unlabeled_X, labeled_edges, unlabeled_edges)

stellar = STELLAR(args, dataset)
stellar.train()
_, results = stellar.pred()
np.save(os.path.join(args.savedir, args.dataset+'_epoch:'+str(args.epochs)+'_batch:'+str(args.batch_size)+'_wd:'+str(args.wd)+'_results.npy'), results)
# Out:
# (14077, 32)
# (3520, 32)
# [INFO]: Training starts
# ####### [2 2 2 ... 2 2 4]
# #######class instances [[   2 2315]
#  [   4 1205]]
# /usr/local/lib/python3.9/dist-packages/torch_geometric/deprecation.py:22: UserWarning: 'data.ClusterData' is deprecated, use 'loader.ClusterData' instead
#   warnings.warn(out)
# Computing METIS partitioning...
# Done!
# /usr/local/lib/python3.9/dist-packages/torch_geometric/deprecation.py:22: UserWarning: 'data.ClusterLoader' is deprecated, use 'loader.ClusterLoader' instead
#   warnings.warn(out)
# Combined Loss: 2.955599
# Acc: 0.0766
# ####### [2 2 2 ... 2 2 4]
# #######class instances [[   2 2315]
#  [   4 1205]]
# Computing METIS partitioning...
# Done!
# Combined Loss: 2.539222
# Acc: 0.1049
# ####### [2 0 0 ... 0 0 4]
# #######class instances [[   0 1775]
#  [   2  540]
#  [   4 1205]]
# Computing METIS partitioning...
# Done!
# Combined Loss: 2.237110
# Acc: 0.3005
# ####### [0 0 0 ... 0 0 4]
# #######class instances [[   0 2315]
#  [   4 1205]]
# Computing METIS partitioning...
# Done!
# Combined Loss: 2.040193
# Acc: 0.3217
# ####### [0 0 0 ... 0 0 4]
# #######class instances [[   0 2315]
#  [   4 1205]]
# Computing METIS partitioning...
# Done!
# Combined Loss: 1.925755
# Acc: 0.2636
# ####### [9 0 0 ... 0 0 4]
# #######class instances [[   0 1764]
#  [   4 1205]
#  [   9  551]]
# Computing METIS partitioning...
# Done!
# Combined Loss: 1.861607
# Acc: 0.2933
# ####### [9 9 0 ... 9 9 4]
# #######class instances [[   0  510]
#  [   4 1205]
#  [   9 1805]]
# Computing METIS partitioning...
# Done!
# Combined Loss: 1.822805
# Acc: 0.3989
# ####### [9 9 0 ... 0 9 4]
# #######class instances [[   0  666]
#  [   4 1205]
#  [   9 1649]]
# Computing METIS partitioning...
# Done!
# Combined Loss: 1.794262
# Acc: 0.3847
# ####### [9 9 0 ... 0 9 4]
# #######class instances [[   0  523]
#  [   4 1205]
#  [   9 1792]]
# Computing METIS partitioning...
# Done!
# Combined Loss: 1.770727
# Acc: 0.4070
# ####### [9 9 0 ... 0 9 4]
# #######class instances [[   0  669]
#  [   4 1205]
#  [   9 1646]]
# Computing METIS partitioning...
# Done!
# Combined Loss: 1.754518
# Acc: 0.4004
# ####### [9 9 0 ... 0 9 4]
# #######class instances [[   0  599]
#  [   4 1205]
#  [   9 1716]]
# Computing METIS partitioning...
# Done!
# Combined Loss: 1.743023
# Acc: 0.3997
# ####### [9 9 0 ... 9 9 4]
# #######class instances [[   0  509]
#  [   4 1205]
#  [   9 1806]]
# Computing METIS partitioning...
# Done!
# Combined Loss: 1.733812
# Acc: 0.4028
# ####### [9 9 0 ... 0 9 4]
# #######class instances [[   0  539]
#  [   4 1205]
#  [   9 1776]]
# Computing METIS partitioning...
# Done!
# Combined Loss: 1.726539
# Acc: 0.4008
# ####### [9 9 0 ... 9 9 4]
# #######class instances [[   0  486]
#  [   4 1205]
#  [   9 1829]]
# Computing METIS partitioning...
# Done!
# Combined Loss: 1.720990
# Acc: 0.4020
# ####### [9 9 0 ... 0 9 4]
# #######class instances [[   0  533]
#  [   4 1196]
#  [   5    9]
#  [   9 1782]]
# Computing METIS partitioning...
# Done!
# Combined Loss: 1.715106
# Acc: 0.4067
# ####### [9 9 0 ... 9 9 4]
# #######class instances [[   0  431]
#  [   4 1108]
#  [   5   97]
#  [   9 1884]]
# Computing METIS partitioning...
# Done!
# Combined Loss: 1.709952
# Acc: 0.4165
# ####### [9 9 0 ... 9 9 5]
# #######class instances [[   0  482]
#  [   4  930]
#  [   5  275]
#  [   9 1833]]
# Computing METIS partitioning...
# Done!
# Combined Loss: 1.705888
# Acc: 0.4193
# ####### [9 9 0 ... 9 9 5]
# #######class instances [[   0  398]
#  [   4  782]
#  [   5  423]
#  [   9 1917]]
# Computing METIS partitioning...
# Done!
# Combined Loss: 1.702560
# Acc: 0.4355
# ####### [9 9 0 ... 9 9 5]
# #######class instances [[   0  384]
#  [   4  625]
#  [   5  580]
#  [   9 1931]]
# Computing METIS partitioning...
# Done!
# Combined Loss: 1.699769
# Acc: 0.4141
# ####### [9 9 0 ... 9 9 5]
# #######class instances [[   0  497]
#  [   4  407]
#  [   5  798]
#  [   9 1818]]
# Computing METIS partitioning...
# Done!
# Combined Loss: 1.695980
# Acc: 0.4124
# Highest Accuracy: 0.435
# ####### [9 9 0 ... 0 9 5]
# #######class instances [[   0  521]
#  [   4  270]
#  [   5  935]
#  [   9 1794]]

# %%
# files = [file_name for file_name in os.listdir("/content/experiments/stellar-main/MouseLymph_STELLAR/") ]
# for file_name in files:
#   np.load(file_name)
# Out:
# array([12, 12, 12, ..., 12, 12, 12])

# %%
import anndata
adata = anndata.AnnData(unlabeled_X)
results = results.astype('object')
for i in range(len(results)):
    if results[i] in inverse_dict.keys():
        results[i] = inverse_dict[results[i]]
adata.obs['pred'] = pd.Categorical(results)
sc.pp.neighbors(adata)
sc.tl.umap(adata)
sc.pl.umap(adata, color=['pred'], size=5)
# Out:
# /usr/local/lib/python3.9/dist-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
adata = anndata.AnnData(labeled_X)
results = labeled_y.astype('object')
for i in range(len(results)):
    if results[i] in inverse_dict.keys():
        results[i] = inverse_dict[results[i]]
adata.obs['pred'] = pd.Categorical(results)
sc.pp.neighbors(adata)
sc.tl.umap(adata)
sc.pl.umap(adata, color=['pred'], size=5)
# Out:
# /usr/local/lib/python3.9/dist-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
